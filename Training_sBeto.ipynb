# %%
# %%capture
# !wget https://users.dcc.uchile.cl/~jperez/beto/cased_2M/pytorch_weights.tar.gz 
# !wget https://users.dcc.uchile.cl/~jperez/beto/cased_2M/vocab.txt 
# !tar -xzvf pytorch_weights.tar.gz
# !mv vocab.txt pytorch/.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Mar 23 17:39:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.103.01   Driver Version: 470.103.01   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A30          On   | 00000000:02:00.0 Off |                    0 |
# | N/A   28C    P0    51W / 165W |   5070MiB / 24258MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA A10          On   | 00000000:84:00.0 Off |                    0 |
# |  0%   90C    P0   126W / 150W |   6240MiB / 22731MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A    165004      C   python                            243MiB |
# |    0   N/A  N/A    165007      C   python                            243MiB |
# |    0   N/A  N/A    165010      C   python                            243MiB |
# |    0   N/A  N/A    165014      C   python                            243MiB |
# |    0   N/A  N/A    165019      C   python                            243MiB |
# |    0   N/A  N/A    165022      C   python                            243MiB |
# |    0   N/A  N/A    165026      C   python                            243MiB |
# |    0   N/A  N/A    165029      C   python                            243MiB |
# |    0   N/A  N/A    165033      C   python                            243MiB |
# |    0   N/A  N/A    165037      C   python                            243MiB |
# |    0   N/A  N/A    165041      C   python                            243MiB |
# |    0   N/A  N/A    167233      C   python                            239MiB |
# |    0   N/A  N/A    167236      C   python                            239MiB |
# |    0   N/A  N/A    167239      C   python                            239MiB |
# |    0   N/A  N/A    167242      C   python                            239MiB |
# |    0   N/A  N/A    167245      C   python                            239MiB |
# |    0   N/A  N/A    167248      C   python                            239MiB |
# |    0   N/A  N/A    167251      C   python                            239MiB |
# |    0   N/A  N/A    167257      C   python                            239MiB |
# |    0   N/A  N/A    167260      C   python                            239MiB |
# |    0   N/A  N/A    167263      C   python                            239MiB |
# |    1   N/A  N/A    196618      C   ...PU/bin/autodock_gpu_128wi     2271MiB |
# |    1   N/A  N/A   3806038      C   ...onda3/envs/rud/bin/python     3893MiB |
# +-----------------------------------------------------------------------------+

# %%
import math
from sentence_transformers import models, losses, datasets
from sentence_transformers import LoggingHandler, SentenceTransformer, util, InputExample
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
import logging
from datetime import datetime
import sys
import os
import gzip
import csv
import random
import json
import requests
import pandas as pd

# %%
config_beto = {
  "architectures": [
    "BertModel"
  ],
  "attention_probs_dropout_prob": 0.1,
  "bos_token_id": 2,
  "cls_token_id": 2,
  "eos_token_id": 3,
  "gradient_checkpointing": False,
  "hidden_act": "gelu",
  "hidden_dropout_prob": 0.1,
  "hidden_size": 768,
  "initializer_range": 0.02,
  "intermediate_size": 3072,
  "layer_norm_eps": 1e-12,
  "mask_token_id": 4,
  "max_position_embeddings": 512,
  "model_type": "bert",
  "num_attention_heads": 12,
  "num_hidden_layers": 12,
  "pad_token_id": 0,
  "position_embedding_type": "absolute",
  "sep_token_id": 3,
  # "tokenizer_class": "DebertaV2Tokenizer",
  "torch_dtype": "float32",
  "transformers_version": "4.9.1",
  "type_vocab_size": 2,
  "unk_token_id": 1,
  "use_cache": True,
  "vocab_size": 31002
}

with open('pytorch/config.json', 'w') as outfile:
    json.dump(config_beto, outfile)

# %%
#### Just some code to print debug information to stdout
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()])

# %%
#### /print debug information to stdout

model_path = 'pytorch/'
train_batch_size = 100          #The larger you select this, the better the results (usually). But it requires more GPU memory
max_seq_length = 75
num_epochs = 20

# Save path of the model
model_save_path = 'output/training_nli_beto'+'-'+datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
model_save_path
# Out:
# 'output/training_nli_beto-2022-03-23_17-57-01'

# %%
# !mv pytorch_weights.tar.gz pytorch

# %%
# !ls pytorch/
# Out:
# config.json  pytorch_model.bin	pytorch_weights.tar.gz	vocab.txt

# %%
# from transformers import AutoConfig, AutoModel, AutoTokenizer

# config = AutoConfig.from_pretrained(model_path)
# auto_model = AutoModel.from_pretrained(model_path)
# tokenizer = AutoTokenizer.from_pretrained(model_path)

# %%
# Here we define our SentenceTransformer model
word_embedding_model = models.Transformer(model_path, max_seq_length=max_seq_length)
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension(), pooling_mode='mean')
model = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# Some weights of the model checkpoint at pytorch/ were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 2022-03-23 18:03:06 - Use pytorch device: cuda

# %%
# from torch import nn
# from transformers import AutoModel, AutoTokenizer, AutoConfig
# import json
# from typing import List, Dict, Optional, Union, Tuple
# import os

# %%
## Getting data
esxnli = 'https://raw.githubusercontent.com/artetxem/esxnli/master/esxnli.tsv'

# %%
esxnli_dataset_path = 'esxnli.tsv'

if not os.path.exists(esxnli_dataset_path):
    util.http_get('https://raw.githubusercontent.com/artetxem/esxnli/master/esxnli.tsv', esxnli_dataset_path)

# %%
# pd.read_csv('data/esxnli.tsv', sep='\t').head()

# %%
# Read the AllNLI.tsv.gz file and create the training dataset
logging.info("Read ESxNLI train dataset")
# Out:
# 2022-03-23 17:57:06 - Read ESxNLI train dataset

# %%
train_data = {}

def add_to_samples(sent1, sent2, label):
    if sent1 not in train_data:
        train_data[sent1] = {'contradiction': set(), 'entailment': set(), 'neutral': set()}
    train_data[sent1][label].add(sent2)

# %%
with open('esxnli.tsv') as dataset:
  reader = csv.DictReader(dataset, delimiter='\t', quoting=csv.QUOTE_NONE)
  for row in reader:
    if row['language'] == 'es':
      
      sent1 = row['sentence1'].strip()
      sent2 = row['sentence2'].strip()
    
      add_to_samples(sent1, sent2, row['gold_label'])
      add_to_samples(sent2, sent1, row['gold_label'])  #Also add the opposite

# %%
train_samples = []
for sent1, others in train_data.items():
    if len(others['entailment']) > 0 and len(others['contradiction']) > 0:
        train_samples.append(InputExample(texts=[sent1, random.choice(list(others['entailment'])), random.choice(list(others['contradiction']))]))
        train_samples.append(InputExample(texts=[random.choice(list(others['entailment'])), sent1, random.choice(list(others['contradiction']))]))

logging.info("Train samples: {}".format(len(train_samples)))
# Out:
# 2022-03-23 18:03:26 - Train samples: 1660

# %%
# Special data loader that avoid duplicates within a batch
train_dataloader = datasets.NoDuplicatesDataLoader(train_samples, batch_size=train_batch_size)


# Our training loss
train_loss = losses.MultipleNegativesRankingLoss(model)

# %%
sts_root = 'sts2015-es'
sts_files = [('STS.gs.newswire.txt', 'STS.input.newswire.txt'),
             ('STS.gs.wikipedia.txt', 'STS.input.wikipedia.txt')]

dev_examples = []
for gs_fname, sents_fname in sts_files:
    gs = open(os.path.join(sts_root, gs_fname))
    sents = open(os.path.join(sts_root, sents_fname))
    for g, s in zip(gs, sents):
        sent1, sent2 = s.split('\t')
        dp = InputExample(texts=[sent1, sent2], label=float(g))
        dev_examples.append(dp)
gs.close()
sents.close()
    
evaluator = EmbeddingSimilarityEvaluator.from_input_examples(dev_examples, batch_size=32,
                                                             name='sts-dev')

# %%
# Configure the training
warmup_steps = math.ceil(len(train_dataloader) * num_epochs * 0.1) #10% of train data for warm-up
logging.info("Warmup-steps: {}".format(warmup_steps))
# Out:
# 2022-03-23 18:03:32 - Warmup-steps: 32

# %%
# Train the model
model.fit(train_objectives=[(train_dataloader, train_loss)],
          # evaluator=dev_evaluator,
          epochs=num_epochs,
          evaluation_steps=1,
          warmup_steps=warmup_steps,
          evaluator=evaluator,
          output_path=model_save_path,
          use_amp=True          #Set to True, if your GPU supports FP16 operations
          )
# Out:
# /users/mmazuecos/miniconda3/envs/rud/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# 2022-03-23 18:04:27 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 1 steps:
# 2022-03-23 18:04:30 - Cosine-Similarity :	Pearson: 0.5603	Spearman: 0.4844
# 2022-03-23 18:04:30 - Manhattan-Distance:	Pearson: 0.5526	Spearman: 0.4798
# 2022-03-23 18:04:30 - Euclidean-Distance:	Pearson: 0.5530	Spearman: 0.4796
# 2022-03-23 18:04:30 - Dot-Product-Similarity:	Pearson: 0.2996	Spearman: 0.2306
# 2022-03-23 18:04:30 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:04:31 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 0:
# 2022-03-23 18:04:34 - Cosine-Similarity :	Pearson: 0.5603	Spearman: 0.4844
# 2022-03-23 18:04:34 - Manhattan-Distance:	Pearson: 0.5526	Spearman: 0.4798
# 2022-03-23 18:04:34 - Euclidean-Distance:	Pearson: 0.5530	Spearman: 0.4796
# 2022-03-23 18:04:34 - Dot-Product-Similarity:	Pearson: 0.2996	Spearman: 0.2306
# 2022-03-23 18:04:35 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 2 steps:
# 2022-03-23 18:04:38 - Cosine-Similarity :	Pearson: 0.5603	Spearman: 0.4844
# 2022-03-23 18:04:38 - Manhattan-Distance:	Pearson: 0.5526	Spearman: 0.4798
# 2022-03-23 18:04:38 - Euclidean-Distance:	Pearson: 0.5530	Spearman: 0.4796
# 2022-03-23 18:04:38 - Dot-Product-Similarity:	Pearson: 0.2996	Spearman: 0.2306
# 2022-03-23 18:04:38 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 0:
# 2022-03-23 18:04:40 - Cosine-Similarity :	Pearson: 0.5603	Spearman: 0.4844
# 2022-03-23 18:04:40 - Manhattan-Distance:	Pearson: 0.5526	Spearman: 0.4798
# 2022-03-23 18:04:40 - Euclidean-Distance:	Pearson: 0.5530	Spearman: 0.4796
# 2022-03-23 18:04:40 - Dot-Product-Similarity:	Pearson: 0.2996	Spearman: 0.2306
# 2022-03-23 18:04:41 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 3 steps:
# 2022-03-23 18:04:45 - Cosine-Similarity :	Pearson: 0.5608	Spearman: 0.4845
# 2022-03-23 18:04:45 - Manhattan-Distance:	Pearson: 0.5530	Spearman: 0.4800
# 2022-03-23 18:04:45 - Euclidean-Distance:	Pearson: 0.5534	Spearman: 0.4799
# 2022-03-23 18:04:45 - Dot-Product-Similarity:	Pearson: 0.3007	Spearman: 0.2312
# 2022-03-23 18:04:45 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:04:46 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 0:
# 2022-03-23 18
- Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:06:13 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 0:
# 2022-03-23 18:06:16 - Cosine-Similarity :	Pearson: 0.5820	Spearman: 0.5033
# 2022-03-23 18:06:16 - Manhattan-Distance:	Pearson: 0.5720	Spearman: 0.4943
# 2022-03-23 18:06:16 - Euclidean-Distance:	Pearson: 0.5712	Spearman: 0.4930
# 2022-03-23 18:06:16 - Dot-Product-Similarity:	Pearson: 0.3851	Spearman: 0.2975
# 2022-03-23 18:06:17 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 15 steps:
# 2022-03-23 18:06:18 - Cosine-Similarity :	Pearson: 0.5843	Spearman: 0.5056
# 2022-03-23 18:06:18 - Manhattan-Distance:	Pearson: 0.5735	Spearman: 0.4950
# 2022-03-23 18:06:18 - Euclidean-Distance:	Pearson: 0.5725	Spearman: 0.4942
# 2022-03-23 18:06:18 - Dot-Product-Similarity:	Pearson: 0.4002	Spearman: 0.3112
# 2022-03-23 18:06:18 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:06:19 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 0:
# 2022-03-23 18:06:23 - Cosine-Similarity :	Pearson: 0.5843	Spearman: 0.5056
# 2022-03-23 18:06:23 - Manhattan-Distance:	Pearson: 0.5735	Spearman: 0.4950
# 2022-03-23 18:06:23 - Euclidean-Distance:	Pearson: 0.5725	Spearman: 0.4942
# 2022-03-23 18:06:23 - Dot-Product-Similarity:	Pearson: 0.4002	Spearman: 0.3112
# 2022-03-23 18:06:24 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 0 after 16 steps:
# 2022-03-23 18:06:27 - Cosine-Similarity :	Pearson: 0.5863	Spearman: 0.5068
# 2022-03-23 18:06:27 - Manhattan-Distance:	Pearson: 0.5746	Spearman: 0.4951
# 2022-03-23 18:06:27 - Euclidean-Distance:	Pearson: 0.5733	Spearman: 0.4938
# 2022-03-23 18:06:27 - Dot-Product-Similarity:	Pearson: 0.4155	Spearman: 0.3254
# 2022-03-23 18:06:27 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:06:28 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 0:
# 2022-03-23 18:06:31 - Cosine-Similarity :	Pearson: 0.5863	Spearman: 0.5068
# 2022-03-23 18:06:31 - Manhattan-Distance:	Pearson: 0.5746	Spearman: 0.4951
# 2022-03-23 18:06:31 - Euclidean-Distance:	Pearson: 0.5733	Spearman: 0.4938
# 2022-03-23 18:06:31 - Dot-Product-Similarity:	Pearson: 0.4155	Spearman: 0.3254
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# 2022-03-23 18:06:32 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 1 steps:
# 2022-03-23 18:06:35 - Cosine-Similarity :	Pearson: 0.5878	Spearman: 0.5082
# 2022-03-23 18:06:35 - Manhattan-Distance:	Pearson: 0.5748	Spearman: 0.4952
# 2022-03-23 18:06:35 - Euclidean-Distance:	Pearson: 0.5731	Spearman: 0.4935
# 2022-03-23 18:06:35 - Dot-Product-Similarity:	Pearson: 0.4306	Spearman: 0.3398
# 2022-03-23 18:06:35 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:06:36 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 1:
# 2022-03-23 18:06:39 - Cosine-Similarity :	Pearson: 0.5878	Spearman: 0.5082
# 2022-03-23 18:06:39 - Manhattan-Distance:	Pearson: 0.5748	Spearman: 0.4952
# 2022-03-23 18:06:39 - Euclidean-Distance:	Pearson: 0.5731	Spearman: 0.4935
# 2022-03-23 18:06:39 - Dot-Product-Similarity:	Pearson: 0.4306	Spearman: 0.3398
# 2022-03-23 18:06:40 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after
- EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 1:
# 2022-03-23 18:07:09 - Cosine-Similarity :	Pearson: 0.5916	Spearman: 0.5104
# 2022-03-23 18:07:09 - Manhattan-Distance:	Pearson: 0.5709	Spearman: 0.4934
# 2022-03-23 18:07:09 - Euclidean-Distance:	Pearson: 0.5649	Spearman: 0.4875
# 2022-03-23 18:07:09 - Dot-Product-Similarity:	Pearson: 0.4761	Spearman: 0.3981
# 2022-03-23 18:07:10 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 6 steps:
# 2022-03-23 18:07:14 - Cosine-Similarity :	Pearson: 0.5962	Spearman: 0.5136
# 2022-03-23 18:07:14 - Manhattan-Distance:	Pearson: 0.5724	Spearman: 0.4956
# 2022-03-23 18:07:14 - Euclidean-Distance:	Pearson: 0.5660	Spearman: 0.4888
# 2022-03-23 18:07:14 - Dot-Product-Similarity:	Pearson: 0.4792	Spearman: 0.4085
# 2022-03-23 18:07:14 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:07:15 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 1:
# 2022-03-23 18:07:17 - Cosine-Similarity :	Pearson: 0.5962	Spearman: 0.5136
# 2022-03-23 18:07:17 - Manhattan-Distance:	Pearson: 0.5724	Spearman: 0.4956
# 2022-03-23 18:07:17 - Euclidean-Distance:	Pearson: 0.5660	Spearman: 0.4888
# 2022-03-23 18:07:17 - Dot-Product-Similarity:	Pearson: 0.4792	Spearman: 0.4085
# 2022-03-23 18:07:18 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 7 steps:
# 2022-03-23 18:07:20 - Cosine-Similarity :	Pearson: 0.6012	Spearman: 0.5186
# 2022-03-23 18:07:20 - Manhattan-Distance:	Pearson: 0.5756	Spearman: 0.4998
# 2022-03-23 18:07:20 - Euclidean-Distance:	Pearson: 0.5693	Spearman: 0.4937
# 2022-03-23 18:07:20 - Dot-Product-Similarity:	Pearson: 0.4777	Spearman: 0.4124
# 2022-03-23 18:07:20 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:07:21 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 1:
# 2022-03-23 18:07:25 - Cosine-Similarity :	Pearson: 0.6012	Spearman: 0.5186
# 2022-03-23 18:07:25 - Manhattan-Distance:	Pearson: 0.5756	Spearman: 0.4998
# 2022-03-23 18:07:25 - Euclidean-Distance:	Pearson: 0.5693	Spearman: 0.4937
# 2022-03-23 18:07:25 - Dot-Product-Similarity:	Pearson: 0.4777	Spearman: 0.4124
# 2022-03-23 18:07:26 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after 8 steps:
# 2022-03-23 18:07:29 - Cosine-Similarity :	Pearson: 0.6052	Spearman: 0.5245
# 2022-03-23 18:07:29 - Manhattan-Distance:	Pearson: 0.5794	Spearman: 0.5045
# 2022-03-23 18:07:29 - Euclidean-Distance:	Pearson: 0.5735	Spearman: 0.4984
# 2022-03-23 18:07:29 - Dot-Product-Similarity:	Pearson: 0.4744	Spearman: 0.4117
# 2022-03-23 18:07:29 - Save model to output/training_nli_beto-2022-03-23_17-57-01
# 2022-03-23 18:07:30 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 1:
# 2022-03-23 18:07:33 - Cosine-Similarity :	Pearson: 0.6052	Spearman: 0.5245
# 2022-03-23 18:07:33 - Manhattan-Distance:	Pearson: 0.5794	Spearman: 0.5045
# 2022-03-23 18:07:33 - Euclidean-Distance:	Pearson: 0.5735	Spearman: 0.4984
# 2022-03-23 18:07:33 - Dot-Product-Similarity:	Pearson: 0.4744	Spearman: 0.4117
# 2022-03-23 18:07:34 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 1 after
- EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 2:
# 2022-03-23 18:09:00 - Cosine-Similarity :	Pearson: 0.6123	Spearman: 0.5252
# 2022-03-23 18:09:00 - Manhattan-Distance:	Pearson: 0.5920	Spearman: 0.5190
# 2022-03-23 18:09:00 - Euclidean-Distance:	Pearson: 0.5908	Spearman: 0.5179
# 2022-03-23 18:09:00 - Dot-Product-Similarity:	Pearson: 0.4945	Spearman: 0.4199
# 2022-03-23 18:09:01 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 5 steps:
# 2022-03-23 18:09:05 - Cosine-Similarity :	Pearson: 0.6136	Spearman: 0.5265
# 2022-03-23 18:09:05 - Manhattan-Distance:	Pearson: 0.5933	Spearman: 0.5200
# 2022-03-23 18:09:05 - Euclidean-Distance:	Pearson: 0.5923	Spearman: 0.5190
# 2022-03-23 18:09:05 - Dot-Product-Similarity:	Pearson: 0.4974	Spearman: 0.4223
# 2022-03-23 18:09:05 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 2:
# 2022-03-23 18:09:08 - Cosine-Similarity :	Pearson: 0.6136	Spearman: 0.5265
# 2022-03-23 18:09:08 - Manhattan-Distance:	Pearson: 0.5933	Spearman: 0.5200
# 2022-03-23 18:09:08 - Euclidean-Distance:	Pearson: 0.5923	Spearman: 0.5190
# 2022-03-23 18:09:08 - Dot-Product-Similarity:	Pearson: 0.4974	Spearman: 0.4223
# 2022-03-23 18:09:09 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 6 steps:
# 2022-03-23 18:09:13 - Cosine-Similarity :	Pearson: 0.6152	Spearman: 0.5278
# 2022-03-23 18:09:13 - Manhattan-Distance:	Pearson: 0.5948	Spearman: 0.5216
# 2022-03-23 18:09:13 - Euclidean-Distance:	Pearson: 0.5939	Spearman: 0.5205
# 2022-03-23 18:09:13 - Dot-Product-Similarity:	Pearson: 0.4997	Spearman: 0.4251
# 2022-03-23 18:09:13 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 2:
# 2022-03-23 18:09:16 - Cosine-Similarity :	Pearson: 0.6152	Spearman: 0.5278
# 2022-03-23 18:09:16 - Manhattan-Distance:	Pearson: 0.5948	Spearman: 0.5216
# 2022-03-23 18:09:16 - Euclidean-Distance:	Pearson: 0.5939	Spearman: 0.5205
# 2022-03-23 18:09:16 - Dot-Product-Similarity:	Pearson: 0.4997	Spearman: 0.4251
# 2022-03-23 18:09:17 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 7 steps:
# 2022-03-23 18:09:20 - Cosine-Similarity :	Pearson: 0.6164	Spearman: 0.5289
# 2022-03-23 18:09:20 - Manhattan-Distance:	Pearson: 0.5959	Spearman: 0.5226
# 2022-03-23 18:09:20 - Euclidean-Distance:	Pearson: 0.5952	Spearman: 0.5211
# 2022-03-23 18:09:20 - Dot-Product-Similarity:	Pearson: 0.5019	Spearman: 0.4274
# 2022-03-23 18:09:20 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 2:
# 2022-03-23 18:09:24 - Cosine-Similarity :	Pearson: 0.6164	Spearman: 0.5289
# 2022-03-23 18:09:24 - Manhattan-Distance:	Pearson: 0.5959	Spearman: 0.5226
# 2022-03-23 18:09:24 - Euclidean-Distance:	Pearson: 0.5952	Spearman: 0.5211
# 2022-03-23 18:09:24 - Dot-Product-Similarity:	Pearson: 0.5019	Spearman: 0.4274
# 2022-03-23 18:09:24 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after
- EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 15 steps:
# 2022-03-23 18:10:21 - Cosine-Similarity :	Pearson: 0.6165	Spearman: 0.5312
# 2022-03-23 18:10:21 - Manhattan-Distance:	Pearson: 0.5938	Spearman: 0.5217
# 2022-03-23 18:10:21 - Euclidean-Distance:	Pearson: 0.5938	Spearman: 0.5212
# 2022-03-23 18:10:21 - Dot-Product-Similarity:	Pearson: 0.5106	Spearman: 0.4324
# 2022-03-23 18:10:21 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 2:
# 2022-03-23 18:10:23 - Cosine-Similarity :	Pearson: 0.6165	Spearman: 0.5312
# 2022-03-23 18:10:23 - Manhattan-Distance:	Pearson: 0.5938	Spearman: 0.5217
# 2022-03-23 18:10:23 - Euclidean-Distance:	Pearson: 0.5938	Spearman: 0.5212
# 2022-03-23 18:10:23 - Dot-Product-Similarity:	Pearson: 0.5106	Spearman: 0.4324
# 2022-03-23 18:10:24 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 2 after 16 steps:
# 2022-03-23 18:10:25 - Cosine-Similarity :	Pearson: 0.6149	Spearman: 0.5304
# 2022-03-23 18:10:25 - Manhattan-Distance:	Pearson: 0.5924	Spearman: 0.5208
# 2022-03-23 18:10:25 - Euclidean-Distance:	Pearson: 0.5924	Spearman: 0.5200
# 2022-03-23 18:10:25 - Dot-Product-Similarity:	Pearson: 0.5111	Spearman: 0.4317
# 2022-03-23 18:10:25 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 2:
# 2022-03-23 18:10:28 - Cosine-Similarity :	Pearson: 0.6149	Spearman: 0.5304
# 2022-03-23 18:10:28 - Manhattan-Distance:	Pearson: 0.5924	Spearman: 0.5208
# 2022-03-23 18:10:28 - Euclidean-Distance:	Pearson: 0.5924	Spearman: 0.5200
# 2022-03-23 18:10:28 - Dot-Product-Similarity:	Pearson: 0.5111	Spearman: 0.4317
# Iteration:   0%|          | 0/16 [00:00<?, ?it/s]
# 2022-03-23 18:10:29 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 3 after 1 steps:
# 2022-03-23 18:10:33 - Cosine-Similarity :	Pearson: 0.6137	Spearman: 0.5296
# 2022-03-23 18:10:33 - Manhattan-Distance:	Pearson: 0.5912	Spearman: 0.5200
# 2022-03-23 18:10:33 - Euclidean-Distance:	Pearson: 0.5913	Spearman: 0.5195
# 2022-03-23 18:10:33 - Dot-Product-Similarity:	Pearson: 0.5115	Spearman: 0.4310
# 2022-03-23 18:10:33 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 3:
# 2022-03-23 18:10:36 - Cosine-Similarity :	Pearson: 0.6137	Spearman: 0.5296
# 2022-03-23 18:10:36 - Manhattan-Distance:	Pearson: 0.5912	Spearman: 0.5200
# 2022-03-23 18:10:36 - Euclidean-Distance:	Pearson: 0.5913	Spearman: 0.5195
# 2022-03-23 18:10:36 - Dot-Product-Similarity:	Pearson: 0.5115	Spearman: 0.4310
# 2022-03-23 18:10:37 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 3 after 2 steps:
# 2022-03-23 18:10:40 - Cosine-Similarity :	Pearson: 0.6127	Spearman: 0.5286
# 2022-03-23 18:10:40 - Manhattan-Distance:	Pearson: 0.5904	Spearman: 0.5198
# 2022-03-23 18:10:40 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5187
# 2022-03-23 18:10:40 - Dot-Product-Similarity:	Pearson: 0.5120	Spearman: 0.4307
# 2022-03-23 18:10:40 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 3:
# 2022-03-23 18:10:43 - Cosine-Similarity :	Pearson: 0.6127	Spearman: 0.5286
# 2022-03-23 18:10:43 - Manhattan-Distance:	Pearson: 0.5904	Spearman: 0.5198
# 2022-03-23 18:10:43 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5187
# 2022-03-23 18:10:43 - Dot-Product-Similarity:	Pearson: 0.5120	Spearman: 0.4307
# 2022-03-23 18:10:44 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 3 after 3 steps:
# 2022-03-23 18:10:48 - Cosine-Similarity :	Pearson: 0.6117	Spearman: 0.5275
# 2022-03-23 18:10:48 - Manhattan-Distance:	Pearson: 0.5896	Spearman: 0.5189
# 2022-03-23 18:10:48 - Euclidean-Distance:	Pearson: 0.5900	Spearman: 0.5179
# 2022-03-23 18:10:48 - Dot-Product-Similarity:	Pearson: 0.5126	Spearman: 0.4299
# 2022-03-23 18:10:48 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 3:
# 2022-03-23 18:10:51 - Cosine-Similarity :	Pearson: 0.6117	Spearman: 0.5275
# 2022-03-23 18:10:51 - Manhattan-Distance:	Pearson: 0.5896	Spearman: 0.5189
# 2022-03-23 18:10:51 - Euclidean-Distance:	Pearson: 0.5900	Spearman: 0.5179
# 2022-03-23 18:10:51 - Dot-Product-Similarity:	Pearson: 0.5126	Spearman: 0.4299
# 2022-03-23 18:10:52 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 3 after 4 steps:
# 2022-03-23 18:10:53 - Cosine-Similarity :	Pearson: 0.6105	Spearman: 0.5263
# 2022-03-23 18:10:53 - Manhattan-Distance:	Pearson: 0.5888	Spearman: 0.5180
# 2022-03-23 18:10:53 - Euclidean-Distance:	Pearson: 0.5894	Spearman: 0.5174
# 2022-03-23 18:10:53 - Dot-Product-Similarity:	Pearson: 0.5128	Spearman: 0.4283
# 2022-03-23 18:10:53 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 3:
# 2022-03-23 18:10:55 - Cosine-Similarity :	Pearson: 0.6105	Spearman: 0.5263
# 2022-03-23 18:10:55 - Manhattan-Distance:	Pearson: 0.5888	Spearman: 0.5180
# 2022-03-23 18:10:55 - Euclidean-Distance:	Pearson: 0.5894	Spearman: 0.5174
# 2022-03-23 18:10:55 - Dot-Product-Similarity:	Pearson: 0.5128	Spearman: 0.4283
# 2022-03-23 18:10:56 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 3 after 5 steps:
# 2022-03-23 18:11:00 - Cosine-Similarity :	Pearson: 0.6099	Spearman: 0.5254
# 2022-03-23 18:11:00 - Manhattan-Distance:	Pearson: 0.5884	Spearman: 0.5181
# 2022-03-23 18:11:00 - Euclidean-Distance:	Pearson: 0.5891	Spearman: 0.5177
# 2022-03-23 18:11:00 - Dot-Product-Similarity:	Pearson: 0.5130	Spearman: 0.4286
# 2022-03-23 18:11:00 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 3:
# 2022-03-23 18:11:03 - Cosine-Similarity :	Pearson: 0.6099	Spearman: 0.5254
# 2022-03-23 18:11:03 - Manhattan-Distance:	Pearson: 0.5884	Spearman: 0.5181
# 2022-03-23 18:11:03 - Euclidean-Distance:	Pearson: 0.5891	Spearman: 0.5177
# 2022-03-23 18:11:03 - Dot-Product-Similarity:	Pearson: 0.5130	Spearman: 0.4286
# 2022-03-23 18:11:04 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 3 after 6 steps:
# 2022-03-23 18:11:07 - Cosine-Similarity :	Pearson: 0.6093	Spearman: 0.5249
# 2022-03-23 18:11:07 - Manhattan-Distance:	Pearson: 0.5880	Spearman: 0.5183
# 2022-03-23 18:11:07 - Euclidean-Distance:	Pearson: 0.5887	Spearman: 0.5181
# 2022-03-23 18:11:07 - Dot-Product-Similarity:	Pearson: 0.5134	Spearman: 0.4294
# 2022-03-23 18:11:07 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch
- Cosine-Similarity :	Pearson: 0.6098	Spearman: 0.5287
# 2022-03-23 18:41:15 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5259
# 2022-03-23 18:41:15 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:15 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:15 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:41:18 - Cosine-Similarity :	Pearson: 0.6098	Spearman: 0.5287
# 2022-03-23 18:41:18 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5259
# 2022-03-23 18:41:18 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:18 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:19 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 19 after 10 steps:
# 2022-03-23 18:41:22 - Cosine-Similarity :	Pearson: 0.6098	Spearman: 0.5288
# 2022-03-23 18:41:22 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:22 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:22 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:22 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:41:26 - Cosine-Similarity :	Pearson: 0.6098	Spearman: 0.5288
# 2022-03-23 18:41:26 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:26 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:26 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:27 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 19 after 11 steps:
# 2022-03-23 18:41:30 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:30 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5259
# 2022-03-23 18:41:30 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:30 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:30 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:41:33 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:33 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5259
# 2022-03-23 18:41:33 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:33 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:34 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 19 after 12 steps:
# 2022-03-23 18:41:37 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:37 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:37 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:37 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:37 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:41:39 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:39 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:39 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:39 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:40 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 19 after 13 steps:
# 2022-03-23 18:41:42 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:42 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:42 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:42 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:42 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:41:45 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:45 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:45 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:45 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:46 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 19 after 14 steps:
# 2022-03-23 18:41:49 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:49 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:49 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:49 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4605
# 2022-03-23 18:41:49 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:41:53 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:53 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5258
# 2022-03-23 18:41:53 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:53 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4605
# 2022-03-23 18:41:54 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 19 after 15 steps:
# 2022-03-23 18:41:57 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:41:57 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5257
# 2022-03-23 18:41:57 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:41:57 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:41:57 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:42:00 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:42:00 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5257
# 2022-03-23 18:42:00 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:42:00 - Dot-Product-Similarity:	Pearson: 0.5441	Spearman: 0.4604
# 2022-03-23 18:42:01 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset in epoch 19 after 16 steps:
# 2022-03-23 18:42:05 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:42:05 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5259
# 2022-03-23 18:42:05 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:42:05 - Dot-Product-Similarity:	Pearson: 0.5440	Spearman: 0.4604
# 2022-03-23 18:42:05 - EmbeddingSimilarityEvaluator: Evaluating the model on sts-dev dataset after epoch 19:
# 2022-03-23 18:42:08 - Cosine-Similarity :	Pearson: 0.6097	Spearman: 0.5287
# 2022-03-23 18:42:08 - Manhattan-Distance:	Pearson: 0.5891	Spearman: 0.5259
# 2022-03-23 18:42:08 - Euclidean-Distance:	Pearson: 0.5906	Spearman: 0.5265
# 2022-03-23 18:42:08 - Dot-Product-Similarity:	Pearson: 0.5440	Spearman: 0.4604

# %%
import pandas as pd

df = pd.read_csv('/users/mmazuecos/somos_nlp/output/training_nli_beto-2022-03-23_17-57-01/eval/similarity_evaluation_sts-dev_results.csv')
df
# Out:
#      epoch  steps  cosine_pearson  cosine_spearman  euclidean_pearson  \
# 0        0     -1        0.560276         0.484379           0.552980
# 1        0     -1        0.560276         0.484379           0.552980
# 2        0     -1        0.560617         0.484452           0.553261
# 3        0     -1        0.561365         0.485106           0.553903
# 4        0     -1        0.562467         0.486193           0.554843
# ..     ...    ...             ...              ...                ...
# 690     19     -1        0.609721         0.528749           0.590559
# 691     19     15        0.609733         0.528677           0.590569
# 692     19     -1        0.609733         0.528677           0.590569
# 693     19     16        0.609713         0.528726           0.590555
# 694     19     -1        0.609713         0.528726           0.590555
#
#      euclidean_spearman  manhattan_pearson  manhattan_spearman  dot_pearson  \
# 0              0.479646           0.552597            0.479779     0.299552
# 1              0.479646           0.552597            0.479779     0.299552
# 2              0.479957           0.552885            0.480021     0.300716
# 3              0.480507           0.553543            0.480300     0.303176
# 4              0.481195           0.554522            0.480866     0.306947
# ..                  ...                ...                 ...          ...
# 690            0.526487           0.589056            0.525800     0.544053
# 691            0.526479           0.589068            0.525738     0.544072
# 692            0.526479           0.589068            0.525738     0.544072
# 693            0.526515           0.589054            0.525850     0.544049
# 694            0.526515           0.589054            0.525850     0.544049
#
#      dot_spearman
# 0        0.230628
# 1        0.230628
# 2        0.231258
# 3        0.232707
# 4        0.235153
# ..            ...
# 690      0.460484
# 691      0.460402
# 692      0.460402
# 693      0.460358
# 694      0.460358
#
# [695 rows x 10 columns]

# %%
# model = SentenceTransformer(model_save_path)

# %%
# !transformers-cli login

# %%
# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# Out:
# Detected operating system as Ubuntu/bionic.
# Checking for curl...
# Detected curl...
# Checking for gpg...
# Detected gpg...
# Running apt-get update... done.
# Installing apt-transport-https... done.
# Installing /etc/apt/sources.list.d/github_git-lfs.list...done.
# Importing packagecloud gpg key... done.
# Running apt-get update... done.
#
# The repository is setup! You can now install packages.

# %%
# !sudo apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-lfs
# 0 upgraded, 1 newly installed, 0 to remove and 98 not upgraded.
# Need to get 6,229 kB of archives.
# After this operation, 14.5 MB of additional disk space will be used.
# Get:1 https://packagecloud.io/github/git-lfs/ubuntu bionic/main amd64 git-lfs amd64 2.13.3 [6,229 kB]
# Fetched 6,229 kB in 1s (6,947 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package git-lfs.
# (Reading database ... 160841 files and directories currently installed.)
# Preparing to unpack .../git-lfs_2.13.3_amd64.deb ...
# Unpacking git-lfs (2.13.3) ...
# Setting up git-lfs (2.13.3) ...
# Git LFS initialized.
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !git lfs install
# Out:
# Git LFS initialized.

# %%
model.save_to_hub('sentece-embeddings-BETO')
# Out:
# 2021-08-08 01:26:51 - Create repository and clone it if it exists
# 2021-08-08 01:26:51 - git version 2.17.1
# git-lfs/2.13.3 (GitHub; linux amd64; go 1.16.2)
# 2021-08-08 01:26:51 - Save model to /tmp/tmpe8otb7zy
# 2021-08-08 01:26:53 - Track files with git lfs: pytorch_model.bin
# 2021-08-08 01:26:53 - Push model to the hub. This might take a while
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/repository.py in git_push(self)
#     417                 encoding="utf-8",
# --> 418                 cwd=self.local_dir,
#     419             )
#
# /usr/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['git', 'push']' returned non-zero exit status 128.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-41-1744ee1e6053> in <module>()
# ----> 1 model.save_to_hub('sentece-embeddings-BETO')
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/SentenceTransformer.py in save_to_hub(self, repo_name, organization, private, commit_message, local_model_path, exist_ok, replace_model_card)
#     483
#     484             logging.info("Push model to the hub. This might take a while")
# --> 485             push_return = repo.push_to_hub(commit_message=commit_message)
#     486
#     487             def on_rm_error(func, path, exc_info):
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/repository.py in push_to_hub(self, commit_message)
#     432         self.git_add()
#     433         self.git_commit(commit_message)
# --> 434         return self.git_push()
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/repository.py in git_push(self)
#     420             logger.info(result.stdout)
#     421         except subprocess.CalledProcessError as exc:
# --> 422             raise EnvironmentError(exc.stderr)
#     423
#     424         return self.git_head_commit_url()
#
# OSError: fatal: could not read Username for 'https://huggingface.co': No such device or address

# %%
# !git config --global user.email "espejelomar@gmail.com"
# !git config --global user.name  "espejelomar"
